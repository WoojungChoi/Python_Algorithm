# 546  21356            0  37.27891  127.0031     19  2018-04-30 13:12:10
# 547  21356            0  37.27883  127.0033     41  2018-04-30 13:12:12
# 548  21356            0  37.26380  127.0059     22  2018-04-30 15:19:13
# 549  21356            0  37.26378  127.0061     49  2018-04-30 15:19:15
# 550  21356            0  37.25671  127.0365     36  2018-05-07 18:13:12
# 551  21356            0  37.25674  127.0362     60  2018-05-07 18:13:14
# 552  21356            0  37.25723  127.0342      5  2018-05-07 18:14:18
# 553  21356            0  37.25724  127.0342     35  2018-05-07 18:14:20
# 554  21356            0  37.25814  127.0307     17  2018-05-07 18:15:35
# 555  21356            0  37.25822  127.0304     56  2018-05-07 18:15:38
# 556  21356            0  37.25999  127.0243     24  2018-05-07 18:16:15
# 557  21356            0  37.26003  127.0240     46  2018-05-07 18:16:17
# 558  21356            0  37.26343  127.0102      2  2018-05-11 08:49:40
# 559  21356            0  37.26343  127.0102     24  2018-05-11 08:49:42
# 560  21356            0  37.26397  127.0012      4  2018-05-11 08:51:26
# 561  21356            0  37.26395  127.0013     31  2018-05-11 08:51:28
# 562  21356            0  37.26395  127.0013     31  2018-05-11 08:51:28
# 563  21356            0  37.26392  127.0011     56  2018-05-11 08:51:30
# 564  21356            0  37.26126  126.9961     13  2018-05-11 08:53:24
# 565  21356            0  37.26117  126.9962     38  2018-05-11 08:53:26
# 566  21356            0  37.26726  127.0270     10  2018-06-08 13:43:23
# 567  21356            0  37.26735  127.0270     34  2018-06-08 13:43:25
# 568  21356            0  37.26539  127.0634     10  2018-06-08 20:33:54
# 569  21356            0  37.26545  127.0634     33  2018-06-08 20:33:56
#
#     time_state
# 0     previous
# 1      current
# 2     previous
# 3      current
# 4     previous
# 5      current
# 6     previous
# 7      current
# 8     previous
# 9      current
# 10    previous
# 11     current
# 12    previous
# 13     current
# 14    previous
# 15     current
# 16    previous
# 17     current
# 18    previous
# 19     current
# 20    previous
# 21     current
# 22    previous
# 23     current
# 24    previous
# 25     current
# 26    previous
# 27     current
# 28    previous
# 29     current
# ..         ...
# 540   previous
# 541    current
# 542   previous
# 543    current
# 544   previous
# 545    current
# 546   previous
# 547    current
# 548   previous
# 549    current
# 550   previous
# 551    current
# 552   previous
# 553    current
# 554   previous
# 555    current
# 556   previous
# 557    current
# 558   previous
# 559    current
# 560   previous
# 561    current
# 562   previous
# 563    current
# 564   previous
# 565    current
# 566   previous
# 567    current
# 568   previous
# 569    current
#
# [570 rows x 7 columns]

# %%
accel_df[5][0:3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-3dc56ca0e776> in <module>
# ----> 1 accel_df[5][0:3]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5

# %%
accel_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-39bca0f5dec8> in <module>
# ----> 1 accel_df[5]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5
